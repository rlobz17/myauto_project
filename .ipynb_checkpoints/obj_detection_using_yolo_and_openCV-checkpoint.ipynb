# %%
import cv2
import DetectCar as car
import numpy as np
import matplotlib.pyplot as plt

# %%
net = cv2.dnn.readNet("../myauto_project_data/model_data/yolov3-tiny.weights", "../myauto_project_data/model_data/yolov3-tiny.cfg")
classes = []
with open("../myauto_project_data/model_data/coco.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]

# %%
layer_names = net.getLayerNames()
outputlayers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# %%
#TODO: change it to iter through every pic
img = cv2.imread("../myauto_project_data/images/23248/4.jpg")
img = cv2.resize(img, (416,416))
# cv2.startWindowThread()
# cv2.imshow("random Image", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img)

# %%
blob = cv2.dnn.blobFromImage(img, 0.004, (416, 416), (0,0,0), True, crop=False)

# %%
fig=plt.figure(figsize=(64, 64))
for b in blob:
    for n, img_blob in enumerate(b):
        fig.add_subplot(16,16, n+1)
        plt.imshow(img_blob)

# %%
net.setInput(blob)
outs = net.forward(outputlayers)

# %%
for out in outs:
    for detection in out:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]
        if confidence > 0.5:
            print("found", str(classes[class_id]), "with", confidence, "percent")
# Out:
# found car with 0.5971284 percent
# found car with 0.76605326 percent

# %%
returnList = car.detect_car("../myauto_project_data/images/70880/1.jpg")
returnList
# Out:
# 0

# %%
import pandas as pd

# %%
dataframe1 = pd.read_csv("../myauto_project_data/model_labels/labels_isCarOnPic _1_40000.csv")
dataframe2 = pd.read_csv("../myauto_project_data/model_labels/labels_isCarOnPic_40000_60000.csv")
dataframe3 = pd.read_csv("../myauto_project_data/model_labels/labels_isCarOnPic _60000_80000.csv")

# %%
dataframe1.shape, dataframe2.shape, dataframe3.shape
# Out:
# ((40062, 32), (20031, 32), (20032, 32))

# %%
dataframe = dataframe1.append(dataframe2)
dataframe = dataframe.append(dataframe3)

# %%
dataframe.shape
# Out:
# (80125, 32)

# %%
len(dataframe['ID'].unique())
# Out:
# 80125

# %%
dataframe.to_csv("labels_all.csv")
